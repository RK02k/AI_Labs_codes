# %% [markdown]
# 60 40 entrophy

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Split data into features and target
X = data_encoded.drop('class', axis=1)
y = data_encoded['class']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, stratify=y)

# Initialize decision tree classifier
clf_ent = DecisionTreeClassifier(criterion='entropy')

# Train the classifier
clf_ent.fit(X_train, y_train)

# Test the classifier
y_pred = clf_ent.predict(X_test)

# Evaluate the classifier
conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")

print("Confusion Matrix:")
print(conf_matrix)
print("\nF1 Score:", f1)
print("\nAccuracy:", accuracy)
# Out:
# Confusion Matrix:
# [[483   1   0   0]
#  [  3 148   3   0]
#  [  0   6  22   0]
#  [  0   3   0  23]]
#
# F1 Score: 0.9765319856908646
#
# Accuracy: 0.976878612716763

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Visualize the decision tree
plt.figure(figsize=(20, 10))
plot_tree(clf_ent, feature_names=X.columns,
          class_names=list(class_mapping.keys()), filled=True)

# Save the plot with high quality
plt.savefig('decision_tree.png', dpi=500)  # Adjust dpi for higher quality
plt.show()

# %% [markdown]
# 60 40 entrophy 20 times

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, stratify=y)

    # Initialize decision tree classifier
    clf_ent_20 = DecisionTreeClassifier(criterion='entropy')

    # Train the classifier
    clf_ent_20.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_ent_20.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9508670520231214
# Iteration 2: Accuracy = 0.9667630057803468
# Iteration 3: Accuracy = 0.9783236994219653
# Iteration 4: Accuracy = 0.9710982658959537
# Iteration 5: Accuracy = 0.976878612716763
# Iteration 6: Accuracy = 0.9624277456647399
# Iteration 7: Accuracy = 0.958092485549133
# Iteration 8: Accuracy = 0.9624277456647399
# Iteration 9: Accuracy = 0.9479768786127167
# Iteration 10: Accuracy = 0.9523121387283237
# Iteration 11: Accuracy = 0.953757225433526
# Iteration 12: Accuracy = 0.9638728323699421
# Iteration 13: Accuracy = 0.9667630057803468
# Iteration 14: Accuracy = 0.953757225433526
# Iteration 15: Accuracy = 0.9638728323699421
# Iteration 16: Accuracy = 0.9682080924855492
# Iteration 17: Accuracy = 0.9595375722543352
# Iteration 18: Accuracy = 0.9638728323699421
# Iteration 19: Accuracy = 0.9609826589595376
# Iteration 20: Accuracy = 0.9436416184971098
# Average Accuracy of Classification over 20 iterations: 0.9612716763005779

# %% [markdown]
# 60 40 gini

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Split data into features and target
X = data_encoded.drop('class', axis=1)
y = data_encoded['class']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, stratify=y)

# Initialize decision tree classifier
clf_ent = DecisionTreeClassifier(criterion='gini')

# Train the classifier
clf_ent.fit(X_train, y_train)

# Test the classifier
y_pred = clf_ent.predict(X_test)

# Evaluate the classifier
conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")

print("Confusion Matrix:")
print(conf_matrix)
print("\nAccuracy:", accuracy)
print("\nF1 Score:", f1)
# Out:
# Confusion Matrix:
# [[473  10   1   0]
#  [  5 145   4   0]
#  [  0   1  25   2]
#  [  0   1   0  25]]
#
# Accuracy: 0.9653179190751445
#
# F1 Score: 0.965632403244238

# %% [markdown]
# 60 40 gini 20 times

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, stratify=y)

    # Initialize decision tree classifier
    clf_gini_20 = DecisionTreeClassifier(criterion='gini')

    # Train the classifier
    clf_gini_20.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_gini_20.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9595375722543352
# Iteration 2: Accuracy = 0.9682080924855492
# Iteration 3: Accuracy = 0.9523121387283237
# Iteration 4: Accuracy = 0.9739884393063584
# Iteration 5: Accuracy = 0.958092485549133
# Iteration 6: Accuracy = 0.9609826589595376
# Iteration 7: Accuracy = 0.9653179190751445
# Iteration 8: Accuracy = 0.9494219653179191
# Iteration 9: Accuracy = 0.9552023121387283
# Iteration 10: Accuracy = 0.9638728323699421
# Iteration 11: Accuracy = 0.9393063583815029
# Iteration 12: Accuracy = 0.9566473988439307
# Iteration 13: Accuracy = 0.9552023121387283
# Iteration 14: Accuracy = 0.9378612716763006
# Iteration 15: Accuracy = 0.9494219653179191
# Iteration 16: Accuracy = 0.9494219653179191
# Iteration 17: Accuracy = 0.9682080924855492
# Iteration 18: Accuracy = 0.9696531791907514
# Iteration 19: Accuracy = 0.9523121387283237
# Iteration 20: Accuracy = 0.9667630057803468
# Average Accuracy of Classification over 20 iterations: 0.957586705202312

# %% [markdown]
# 70

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y)

    # Initialize decision tree classifier
    clf_ent_20_70 = DecisionTreeClassifier(criterion='entropy')

    # Train the classifier
    clf_ent_20_70.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_ent_20_70.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9807321772639692
# Iteration 2: Accuracy = 0.9633911368015414
# Iteration 3: Accuracy = 0.9614643545279383
# Iteration 4: Accuracy = 0.9710982658959537
# Iteration 5: Accuracy = 0.953757225433526
# Iteration 6: Accuracy = 0.9788053949903661
# Iteration 7: Accuracy = 0.9807321772639692
# Iteration 8: Accuracy = 0.9749518304431599
# Iteration 9: Accuracy = 0.9653179190751445
# Iteration 10: Accuracy = 0.9402697495183044
# Iteration 11: Accuracy = 0.9749518304431599
# Iteration 12: Accuracy = 0.9730250481695568
# Iteration 13: Accuracy = 0.9595375722543352
# Iteration 14: Accuracy = 0.9499036608863198
# Iteration 15: Accuracy = 0.9672447013487476
# Iteration 16: Accuracy = 0.9865125240847784
# Iteration 17: Accuracy = 0.9865125240847784
# Iteration 18: Accuracy = 0.9614643545279383
# Iteration 19: Accuracy = 0.976878612716763
# Iteration 20: Accuracy = 0.9710982658959537
# Average Accuracy of Classification over 20 iterations: 0.9688824662813103

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y)

    # Initialize decision tree classifier
    clf_gini_20_70 = DecisionTreeClassifier(criterion='gini')

    # Train the classifier
    clf_gini_20_70.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_gini_20_70.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9441233140655106
# Iteration 2: Accuracy = 0.9653179190751445
# Iteration 3: Accuracy = 0.976878612716763
# Iteration 4: Accuracy = 0.9710982658959537
# Iteration 5: Accuracy = 0.9653179190751445
# Iteration 6: Accuracy = 0.9614643545279383
# Iteration 7: Accuracy = 0.9441233140655106
# Iteration 8: Accuracy = 0.9691714836223507
# Iteration 9: Accuracy = 0.9595375722543352
# Iteration 10: Accuracy = 0.9672447013487476
# Iteration 11: Accuracy = 0.9633911368015414
# Iteration 12: Accuracy = 0.9576107899807321
# Iteration 13: Accuracy = 0.9595375722543352
# Iteration 14: Accuracy = 0.9845857418111753
# Iteration 15: Accuracy = 0.953757225433526
# Iteration 16: Accuracy = 0.9633911368015414
# Iteration 17: Accuracy = 0.9633911368015414
# Iteration 18: Accuracy = 0.9633911368015414
# Iteration 19: Accuracy = 0.976878612716763
# Iteration 20: Accuracy = 0.9653179190751445
# Average Accuracy of Classification over 20 iterations: 0.963776493256262

# %% [markdown]
# 80

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y)

    # Initialize decision tree classifier
    clf_ent_20_80 = DecisionTreeClassifier(criterion='entropy')

    # Train the classifier
    clf_ent_20_80.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_ent_20_80.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9653179190751445
# Iteration 2: Accuracy = 0.9710982658959537
# Iteration 3: Accuracy = 0.976878612716763
# Iteration 4: Accuracy = 0.9450867052023122
# Iteration 5: Accuracy = 0.9335260115606936
# Iteration 6: Accuracy = 0.9797687861271677
# Iteration 7: Accuracy = 0.9624277456647399
# Iteration 8: Accuracy = 0.953757225433526
# Iteration 9: Accuracy = 0.9624277456647399
# Iteration 10: Accuracy = 0.9971098265895953
# Iteration 11: Accuracy = 0.9855491329479769
# Iteration 12: Accuracy = 0.9710982658959537
# Iteration 13: Accuracy = 0.9826589595375722
# Iteration 14: Accuracy = 0.9653179190751445
# Iteration 15: Accuracy = 0.9739884393063584
# Iteration 16: Accuracy = 0.9826589595375722
# Iteration 17: Accuracy = 0.9797687861271677
# Iteration 18: Accuracy = 0.9855491329479769
# Iteration 19: Accuracy = 0.9855491329479769
# Iteration 20: Accuracy = 0.976878612716763
# Average Accuracy of Classification over 20 iterations: 0.9718208092485549

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Initialize list to store accuracy scores
accuracy_scores = []

# Repeat the exercise 20 times
for i in range(20):
    # Split data into features and target
    X = data_encoded.drop('class', axis=1)
    y = data_encoded['class']

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y)

    # Initialize decision tree classifier
    clf_gini_20_80 = DecisionTreeClassifier(criterion='gini')

    # Train the classifier
    clf_gini_20_80.fit(X_train, y_train)

    # Test the classifier
    y_pred = clf_gini_20_80.predict(X_test)

    # Calculate accuracy and store it
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Iteration {i+1}: Accuracy = {accuracy}")

# Calculate the average accuracy
average_accuracy = sum(accuracy_scores) / len(accuracy_scores)

print("Average Accuracy of Classification over 20 iterations:", average_accuracy)
# Out:
# Iteration 1: Accuracy = 0.9624277456647399
# Iteration 2: Accuracy = 0.9739884393063584
# Iteration 3: Accuracy = 0.976878612716763
# Iteration 4: Accuracy = 0.9595375722543352
# Iteration 5: Accuracy = 0.9797687861271677
# Iteration 6: Accuracy = 0.9566473988439307
# Iteration 7: Accuracy = 0.976878612716763
# Iteration 8: Accuracy = 0.9710982658959537
# Iteration 9: Accuracy = 0.9682080924855492
# Iteration 10: Accuracy = 0.9797687861271677
# Iteration 11: Accuracy = 0.9566473988439307
# Iteration 12: Accuracy = 0.9884393063583815
# Iteration 13: Accuracy = 0.976878612716763
# Iteration 14: Accuracy = 0.9710982658959537
# Iteration 15: Accuracy = 0.9739884393063584
# Iteration 16: Accuracy = 0.9710982658959537
# Iteration 17: Accuracy = 0.9797687861271677
# Iteration 18: Accuracy = 0.9566473988439307
# Iteration 19: Accuracy = 0.9710982658959537
# Iteration 20: Accuracy = 0.9739884393063584
# Average Accuracy of Classification over 20 iterations: 0.9712427745664739

# %% [markdown]
# last

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score,f1_score
from sklearn.preprocessing import OneHotEncoder

# Load the data
columns = ['buying', 'maint', 'doors',
           'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv("car.data", names=columns)

# Map class labels to numerical values
class_mapping = {'unacc': 0, 'acc': 1, 'good': 2, 'vgood': 3}
data['class'] = data['class'].map(class_mapping)

# Convert categorical features into one-hot encoded representation
categorical_columns = ['buying', 'maint',
                       'doors', 'persons', 'lug_boot', 'safety']
data_encoded = pd.get_dummies(data, columns=categorical_columns)

# Split data into features and target
X = data_encoded.drop('class', axis=1)
y = data_encoded['class']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, stratify=y)

# Initialize decision tree classifier
clf_ent = DecisionTreeClassifier(criterion='entropy')

# Train the classifier
clf_ent.fit(X_train, y_train)

# Test the classifier on testing data
y_pred_test = clf_ent.predict(X_test)

# Evaluate the classifier on testing data
conf_matrix_test = confusion_matrix(y_test, y_pred_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test, average="weighted")

# Test the classifier on training data
y_pred_train = clf_ent.predict(X_train)

# Evaluate the classifier on training data
conf_matrix_train = confusion_matrix(y_train, y_pred_train)
accuracy_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train, average="weighted")

# Print results for testing data
print("Testing Data:")
print("Confusion Matrix:")
print(conf_matrix_test)
print("Accuracy:", accuracy_test)
print("F1 Score:", f1_test)

# Print results for training data
print("\nTraining Data:")
print("Confusion Matrix:")
print(conf_matrix_train)
print("Accuracy:", accuracy_train)
print("F1 Score:", f1_train)
# Out:
# Testing Data:
# Confusion Matrix:
# [[478   6   0   0]
#  [  2 144   7   1]
#  [  0   1  27   0]
#  [  0   2   4  20]]
# Accuracy: 0.9667630057803468
# F1 Score: 0.9674699542597953
#
# Training Data:
# Confusion Matrix:
# [[726   0   0   0]
#  [  0 230   0   0]
#  [  0   0  41   0]
#  [  0   0   0  39]]
# Accuracy: 1.0
# F1 Score: 1.0
